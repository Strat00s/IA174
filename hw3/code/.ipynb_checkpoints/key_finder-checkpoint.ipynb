# %%
import requests

def APICall(difficulty: str, endpoint: str, uco:str, data: dict | None = None):
    url = f"https://ia174.fi.muni.cz/hw03/{difficulty}/{endpoint}/{uco}/"
    print(url)
    if data == None:
        request = requests.get(url)
    else:
        request = requests.post(url, json=data)
    
    if request.status_code != 200:
        print(f"Err {request.status_code}: {request.reason}")
        return None

    return  request.json()

def isGenerator(point, curve):
    factors = [x*y for (x, y) in curve.order().factor()]
    for factor in factors:
        if point * factor == curve.point((0, 1, 0)):
            return False
    return True

n1 = 940258296925944608662895221235664431210
n2 = 42535295865117307932921825928971027169

gen_x = 23738974802862558648298862926228992519830411363340623631850893097053769277762
gen_y = 4527474540349461877783199522381786049485080389766292554055872436429664703463

p = 0x586be5268256ae12d62631efc2784d02dcff420d262da9cd94c62d5808bee24d
a = 0x7e7
b = 0x0

pub_x = 0x1a9112ae9ac6b30cb8f899f9ed76b4c3826b758d5c98a840afd9eee17d09fe73
pub_y = 0x39525bafcf33493141fd3f57d170f69af4ce41cd76ddb0f418781db2b4da5a8c

print("start")

ecurve      = EllipticCurve(GF(p), [a, b])
generator   = ecurve.point((gen_x, gen_y))
pubkey      = ecurve.point((pub_x, pub_y))
order       = ecurve.order()
factors_all = [x*y for (x, y) in order.factor()]
factors     = factors_all[:-1]

print(ecurve)
print(generator)
print(pubkey)
print(order)
print(n1 * n2)
print(factors)

#get random point with small order
so_point = ecurve.point((0, 1, 0))
while so_point.order() != n1:
    rng_point = ecurve.random_point()
    so_point = rng_point * (order // n1)

print(so_point)
print(so_point.order())
print(isGenerator(so_point, ecurve))
so_point = so_point * (n1 // 5)
print(so_point)
print(so_point.order())
print(isGenerator(so_point, ecurve))

data = {"x": f"{hex(so_point[0])}", "y": f"{hex(so_point[1])}"}
print(data)

print(APICall("easy", "ecdh", "492875", data))

oso_point = so_point

for i in range(0, 5):
    print(f"{i + 1}:\nx{i+1}={so_point[0]}\ny{i+1}={so_point[1]}")
    so_point += oso_point
    
#exit()

#generator = so_point

#residues = []
#for factor in factors:
#    a =  generator * (order // factor)
#    b =  pubkey * (order // factor)
#    i = discrete_log(b, a, a.order(), operation='+')
#    residues.append(i)

#print(residues)
#n = crt(residues, factors)
#print(n)
#modulus = prod(factors)
#print(modulus)

#exit()

#while True:
#    if generator * n == pubkey:
#        print(n)
#        break
#    n += modulus
# Out:
# start
# Elliptic Curve defined by y^2 = x^3 + 2023*x over Finite Field of size 39994164849376373681302869279978885783653661374456939385898429379205375386189
# (23738974802862558648298862926228992519830411363340623631850893097053769277762 : 4527474540349461877783199522381786049485080389766292554055872436429664703463 : 1)
# (12016455826322587254171332197242588164952855197335449999871359431274478042739 : 25927346627286978519142378766841887155559783122479065444158612164844671621772 : 1)
# 39994164849376373681302869279978885783260159848204277050736846327351841544490
# 39994164849376373681302869279978885783260159848204277050736846327351841544490
# [2, 5, 13, 17, 29, 37, 41, 53, 61, 73, 89, 97, 101, 109, 113, 137, 149, 157, 173, 181, 193, 197]
# (15630028479556718349778917639304910841695354183437849246109202284323097872009 : 33830112461477554358865326938257995993330844905169253099418207353102786492857 : 1)
# 940258296925944608662895221235664431210
# True
# (20505764540447034780382698967979870626474979143166177786697456341356082769893 : 18463539337054722152441196821332966094533121545849764288493042981572976481439 : 1)
# 5
# False
# {'x': '0x2d55d9f79469f317d0fd1d4d211b71d407b4697b4f59e9fa9e9cde3671262fe5', 'y': '0x28d1fe30b9810b3142dc93a663c49802cf43ed88bc85c8b0fd4a37fd40ba949f'}
# https://ia174.fi.muni.cz/hw03/easy/ecdh/492875/
# {'secret': '6e340b9cffb37a989ca544e6bb780a2c78901d3fb33738768511a30617afa01d'}
# 1:
# x1=20505764540447034780382698967979870626474979143166177786697456341356082769893
# y1=18463539337054722152441196821332966094533121545849764288493042981572976481439
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [32], line 74
#      72 for i in range(Integer(0), Integer(5)):
#      73     print(f"{i + Integer(1)}:\nx{i+Integer(1)}={so_point[Integer(0)]}\ny{i+Integer(1)}={so_point[Integer(1)]}")
# ---> 74     so_point *= so_point
#      76 #exit()
#      77
#      78 #generator = so_point
#    (...)
#      98 #        break
#      99 #    n += modulus
#
# File ~/mambaforge/envs/sage/lib/python3.10/site-packages/sage/schemes/generic/morphism.py:400, in SchemeMorphism.__mul__(self, right)
#     398     return coercion_model.bin_op(self, right, operator.mul)
#     399 if right.codomain() != self.domain():
# --> 400     raise TypeError("self (=%s) domain must equal right (=%s) codomain"%(self, right))
#     401 if isinstance(self, SchemeMorphism_id):
#     402     return right
#
# TypeError: self (=(20505764540447034780382698967979870626474979143166177786697456341356082769893 : 18463539337054722152441196821332966094533121545849764288493042981572976481439 : 1)) domain must equal right (=(20505764540447034780382698967979870626474979143166177786697456341356082769893 : 18463539337054722152441196821332966094533121545849764288493042981572976481439 : 1)) codomain
